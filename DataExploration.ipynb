# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(18.00,10.00)})

# %%
df_flight=pd.read_csv("Merged_weather_flight",index_col=0)

# %%
df_flight.columns
# Out:
# Index(['windspeedKmph', 'windspeedMiles', 'WindGustKmph', 'winddirDegree',
#        'weatherCode', 'precipMM', 'visibility', 'pressure', 'cloudcover',
#        'DewPointF', 'tempF', 'WindChillF', 'humidity', 'time', 'date',
#        'airport', 'Origin', 'Dest', 'FlightDate', 'DepTime', 'DepDel15',
#        'CRSDepTime', 'CRSArrTime', 'DepDelayMinutes', 'OriginAirportID',
#        'DestAirportID', 'ArrTime', 'ArrDel15', 'ArrDelayMinutes', 'Month'],
#       dtype='object')

# %%
sns.histplot(data=df_flight,x="windspeedKmph",stat="count")
# Out:
# <AxesSubplot:xlabel='windspeedKmph', ylabel='Count'>

# %%
df_flight.shape
# Out:
# (4804994, 30)

# %%
group1=df_flight[df_flight["windspeedKmph"]>40]

# %%
group1.groupby(by="ArrDel15").count()
# Out:
#           windspeedKmph  windspeedMiles  WindGustKmph  winddirDegree  \
# ArrDel15
# 0.0                2003            2003          2003           2003
# 1.0                1343            1343          1343           1343
#
#           weatherCode  precipMM  visibility  pressure  cloudcover  DewPointF  \
# ArrDel15
# 0.0              2003      2003        2003      2003        2003       2003
# 1.0              1343      1343        1343      1343        1343       1343
#
#           ...  DepTime  DepDel15  CRSDepTime  CRSArrTime  DepDelayMinutes  \
# ArrDel15  ...
# 0.0       ...     2003      2003        2003        2003             2003
# 1.0       ...     1343      1343        1343        1343             1343
#
#           OriginAirportID  DestAirportID  ArrTime  ArrDelayMinutes  Month
# ArrDel15
# 0.0                  2003           2003     2003             2003   2003
# 1.0                  1343           1343     1343             1343   1343
#
# [2 rows x 29 columns]

# %%
sns.histplot(data=df_flight,x="tempF",stat="count")
# Out:
# <AxesSubplot:xlabel='tempF', ylabel='Count'>

# %%
sns.histplot(data=df_flight,x="humidity",stat="count")
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='Count'>

# %%
sns.histplot(data=df_flight,x="cloudcover",stat="count")
# Out:
# <AxesSubplot:xlabel='cloudcover', ylabel='Count'>

# %%
sns.boxplot(data=df_flight,x="DepDelayMinutes")
# Out:
# <AxesSubplot:xlabel='DepDelayMinutes'>

# %%
sns.boxplot(data=df_flight,x="ArrDelayMinutes")
# Out:
# <AxesSubplot:xlabel='ArrDelayMinutes'>

# %%
sns.boxplot(data=df_flight,x="precipMM")
# Out:
# <AxesSubplot:xlabel='precipMM'>

# %%
sns.boxplot(data=df_flight,x="visibility")
# Out:
# <AxesSubplot:xlabel='visibility'>

# %%
sns.scatterplot(data=df_flight,x="tempF",y='humidity')
# Out:
# <AxesSubplot:xlabel='tempF', ylabel='humidity'>

# %%
sns.scatterplot(data=df_flight,x="windspeedKmph",y="pressure")
# Out:
# <AxesSubplot:xlabel='windspeedKmph', ylabel='pressure'>

# %%
sns.scatterplot(data=df_flight,x="DepDelayMinutes",y="ArrDelayMinutes")
# Out:
# <AxesSubplot:xlabel='DepDelayMinutes', ylabel='ArrDelayMinutes'>

# %%
sns.barplot(data=df_flight,x="weatherCode",y="ArrDel15",estimator=np.sum)
# Out:
# <AxesSubplot:xlabel='weatherCode', ylabel='ArrDel15'>

# %%
group3=df_flight.groupby(by="weatherCode").count()

# %%
group3["ArrDel15"]>10000
# Out:
# weatherCode
# 113     True
# 116     True
# 119     True
# 122     True
# 143     True
# 176     True
# 179    False
# 182    False
# 200     True
# 227    False
# 230    False
# 248     True
# 260    False
# 263    False
# 266     True
# 284    False
# 293     True
# 296     True
# 299    False
# 302     True
# 305    False
# 308     True
# 311    False
# 314    False
# 317    False
# 320    False
# 323    False
# 326     True
# 329    False
# 332    False
# 335    False
# 338    False
# 350    False
# 353     True
# 356     True
# 359    False
# 362    False
# 365    False
# 368    False
# 371    False
# 386     True
# 389     True
# 395    False
# Name: ArrDel15, dtype: bool

# %%
correlation=df_flight.corr()
correlation.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\Omii\AppData\Local\Temp\ipykernel_13224\1434233212.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   correlation.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_fc0e8_row0_col0, #T_fc0e8_row0_col1, #T_fc0e8_row1_col0, #T_fc0e8_row1_col1, #T_fc0e8_row2_col2, #T_fc0e8_row3_col3, #T_fc0e8_row4_col4, #T_fc0e8_row5_col5, #T_fc0e8_row6_col6, #T_fc0e8_row7_col7, #T_fc0e8_row8_col8, #T_fc0e8_row9_col9, #T_fc0e8_row10_col10, #T_fc0e8_row11_col11, #T_fc0e8_row12_col12, #T_fc0e8_row13_col13, #T_fc0e8_row13_col14, #T_fc0e8_row14_col13, #T_fc0e8_row14_col14, #T_fc0e8_row15_col15, #T_fc0e8_row16_col16, #T_fc0e8_row17_col17, #T_fc0e8_row18_col18, #T_fc0e8_row19_col19, #T_fc0e8_row20_col20, #T_fc0e8_row21_col21, #T_fc0e8_row22_col22, #T_fc0e8_row23_col23, #T_fc0e8_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...

# %%
sns.scatterplot(data=df_flight,x="precipMM",y="ArrDelayMinutes",estimator=np.sum)
# Out:
# <AxesSubplot:xlabel='precipMM', ylabel='ArrDelayMinutes'>

# %%
sns.barplot(data=df_flight,x="visibility",y="ArrDel15",estimator=np.sum)
# Out:
# <AxesSubplot:xlabel='visibility', ylabel='ArrDel15'>

# %%
sns.barplot(data=df_flight,x="cloudcover",y="ArrDel15",estimator=np.sum)
plt.xticks(rotation=90);

# %%
sns.barplot(data=df_flight,x="humidity",y="ArrDel15",estimator=np.sum)
plt.xticks(rotation=90);

# %%
df_flight["cloudcover"].describe()
# Out:
# count    4.804994e+06
# mean     4.198709e+01
# std      3.964129e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      3.300000e+01
# 75%      8.300000e+01
# max      1.000000e+02
# Name: cloudcover, dtype: float64

# %%
df_flight["visibility"].describe()
# Out:
# count    4.804994e+06
# mean     9.457986e+00
# std      1.778129e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.000000e+01
# 75%      1.000000e+01
# max      2.000000e+01
# Name: visibility, dtype: float64

# %%
df_flight["humidity"].describe()
# Out:
# count    4.804994e+06
# mean     6.211080e+01
# std      2.229466e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.500000e+01
# 75%      8.000000e+01
# max      1.000000e+02
# Name: humidity, dtype: float64

# %%
df_flight["pressure"].describe()
# Out:
# count    4.804994e+06
# mean     1.016223e+03
# std      6.401458e+00
# min      9.840000e+02
# 25%      1.012000e+03
# 50%      1.016000e+03
# 75%      1.020000e+03
# max      1.046000e+03
# Name: pressure, dtype: float64
